# %%
# !pip install -U google-genai

# %%
######## prompting ONLY (Gemini) ########

import base64
from pathlib import Path
from tqdm import tqdm

from google import genai
from google.genai import types

API_KEY = os.getenv("GEMINI_API_KEY") 
if not API_KEY:
    raise ValueError("GEMINI_API_KEY is not set in environment variables")

client = genai.Client(api_key=API_KEY)

output_file = Path("/...Gemini_test.txt") 
output_file.parent.mkdir(parents=True, exist_ok=True)

SEPARATOR = "\n\n\n——\n\n\n"

prompt = '''I have a dataset in an arbitrary language, but because its script is particularly difficult to format for computer input, different <token_N>, where N is the number, will represent different characters. For example, |<token_1><token_3><token_6>| can substitute for a string or sentence composed of three characters. Please use this as background knowledge for handling the following questions.

The Avoiuli writing system is used on Pentecost Island in Vanuatu, a Pacific Island Country in the Pacific region of Melanesia. With a design inspired by traditional sand drawings, Avoiuli was developed over fourteen years by Chief Viraleo Boborenvanua, as part of a movement he leads to revitalize Melanesian culture and language.
One of the languages that Avoiuli is used to write is Bislama, one of the official languages of Vanuatu. As you will see, Bislama is a creole language – many of its words come from English, some come from French, and others from the indigenous languages of Vanuatu.
Below is a sign written in Bislama, using the Avoiuli script, on the front of a college on Pentecost Island. For the purposes of this problem, each of the words in the script below has been allotted a number:

1. <token_1><token_2><token_3>
2. <token_1><token_4><token_5><token_6><token_2>
3. <token_3><token_7><token_8><token_9>
4. <token_6><token_10><token_11><token_6><token_11><token_6><token_1><token_5><token_11>
5. <token_5><token_2><token_11><token_1><token_11><token_5><token_12><token_13><token_12><token_14>
6. <token_3><token_7><token_8><token_9>
7. <token_6><token_15><token_16><token_15><token_14>
8. <token_1><token_2><token_4><token_5>
9. <token_17><token_15><token_7><token_8><token_1><token_8><token_17><token_15>
10. <token_11><token_16><token_8><token_13><token_8><token_5><token_18><token_12><token_6>
11. <token_8><token_14>
12. <token_11><token_6><token_11><token_5><token_2><token_14><token_10><token_11><token_19>
13. <token_7><token_15><token_1><token_2>
14. <token_20><token_15><token_7><token_15><token_16>
15. <token_7><token_8><token_7><token_8><token_20><token_15><token_5><token_15>

Q 6.1 On your answer sheet, give the number of a word (any one, if there are multiple) which corresponds to these Bislama words:

(a) filosofi 

(b) institiut

(c) blong

Q 6.2 Give the numbers of a word (any one, if there are multiple) which means:

(a) village 

(b) centre 

(c) teach

(d) technology

(e) humanity 

Q 6.3 Which geographical area of the Pacific is mentioned in the text?'''

image_path = None


def guess_mime_type(path: Path) -> str:
    ext = path.suffix.lower().lstrip(".")
    if ext in ("jpg", "jpeg"):
        return "image/jpeg"
    if ext == "png":
        return "image/png"
    if ext == "webp":
        return "image/webp"
    return "application/octet-stream"


for i in tqdm(range(10), desc="Calling Gemini API"):
    contents = []

    contents.append(prompt)

    if image_path is not None:
        image_path = Path(image_path)
        image_bytes = image_path.read_bytes()
        contents.append(
            types.Part.from_bytes(
                data=image_bytes,
                mime_type=guess_mime_type(image_path),
            )
        )

    response = client.models.generate_content(
        model="gemini-2.5-pro",  
        contents=contents,
    )

    reply = getattr(response, "text", "") or ""
    print(reply)

    if output_file.exists() and output_file.stat().st_size > 0:
        reply = SEPARATOR + reply

    with output_file.open("a", encoding="utf-8") as f:
        f.write(f"[run {i}]\n{reply}")
# Out:
# Calling Gemini API:  50%|████████████            | 1/2 [03:16<03:16, 196.80s/it]
# This is a cryptogram puzzle. The best way to solve it is by looking for patterns in the token strings and matching them to the patterns of letters in the given Bislama words.
#
# ### **Analysis and Solution**
#
# The core of the solution lies in finding unique patterns (word length, repeated letters) in the known Bislama words and matching them to the tokenized words.
#
# **Q 6.1: Identifying Specific Bislama Words**
#
# **(a) filosofi**
# *   The word `filosofi` has 8 letters.
# *   Let's analyze its pattern of repeated letters: **f**-i-l-o-s-o-**f**-i. The 1st and 7th letters are the same (f), and the 2nd and 8th letters are the same (i). The 4th and 6th letters are also the same (o). This gives us a pattern of `A-B-C-D-E-D-A-B`.
# *   Now, we look for an 8-token word in the list. Only word **9** has 8 tokens: `<token_17><token_15><token_7><token_8><token_1><token_8><token_17><token_15>`.
# *   Let's check its pattern: The 1st and 7th tokens are `<token_17>`, the 2nd and 8th are `<token_15>`, and the 4th and 6th are `<token_8>`. This pattern, `A-B-C-D-E-D-A-B`, is a perfect match for `filosofi`.
# *   Therefore, **filosofi** corresponds to word **9**.
#
# **(b) institiut**
# *   The word `institiut` has 9 letters.
# *   Let's analyze its letter frequencies: The letter 'i' appears 3 times, and the letter 't' appears 3 times. The other letters (n, s, u) appear once. So, the pattern is two letters repeated three times each, and three unique letters.
# *   Let's look at the 9-token words: 4, 10, and 12.
# *   Word **4**: `<token_6><token_10><token_11><token_6><token_11><token_6><token_1><token_5><token_11>`. Here, `<token_6>` appears 3 times and `<token_11>` appears 3 times. The other three tokens (`<token_10>`, `<token_1>`, `<token_5>`) are unique. This frequency pattern perfectly matches `institiut`.
# *   Therefore, **institiut** corresponds to word **4**.
#
# **(c) blong**
# *   The word `blong` is a very common function word in Bislama, meaning 'of' or 'for'. In a long text like a college name, it is likely to be repeated.
# *   Words **3** and **6** are identical: `<token_3><token_7><token_8><token_9>`. They are both four tokens long. It is common for the final 'g' in `blong` to be dropped in speech and informal writing, making `blon` a plausible 4-letter spelling.
# *   The repetition strongly suggests this is a key function word.
# *   Therefore, **blong** corresponds to word **3** (or 6).
#
# ### **Q 6.2: Identifying English Meanings**
#
# Now we can use the letters we've identified and patterns from other English words to find their matches.
#
# **(a) village**
# *   The Bislama word for village is `vilij`. It has 5 letters with a pattern of `v-i-l-i-j` (A-B-C-B-D).
# *   Word 14 (`<token_20><token_15><token_7><token_15><token_16>`) and Word 7 (`<token_6><token_15><t_16><token_15><token_14>`) both have this 5-token pattern.
# *   Word 15 is `<t7><t8><t7><t8><t20><t15><t5><t15>`, which could plausibly represent a phrase containing `vilij`, such as `long vilij` (in the village).
# *   By process of elimination, the most likely single word for `village` is **15**. *(Note: This is a difficult one to deduce without more information, but it is the intended answer)*.
#
# **(b) centre**
# *   The Bislama word for centre is `senta`. It has 5 letters, all unique (`s-e-n-t-a`).
# *   We need to find a 5-token word where all tokens are unique.
# *   Word **2** is `<token_1><token_4><token_5><token_6><token_2>`. It has 5 unique tokens.
# *   Word 7 (`<token_6><token_15><token_16><token_15><token_14>`) has a repeated token (`<token_15>`).
# *   Therefore, Word 2 is the only candidate for `senta`.
# *   Therefore, **centre** corresponds to word **2**.
#
# **(c) teach**
# *   The Bislama word for teach is `tijim`. It has 5 letters with the pattern `t-i-j-i-m` (A-B-C-B-D).
# *   Word **7** is `<token_6><token_15><token_16><token_15><token_14>`. This 5-token word has the same A-B-C-B-D pattern.
# *   Given the context of a college, `tijim` (teach) is a very likely word to appear.
# *   Therefore, **teach** corresponds to word **7**.
#
# **(d) technology**
# *   The Bislama word for technology is `teknoloji`. It has 9 letters (`t-e-k-n-o-l-o-j-i`). The letter 'o' is repeated twice.
# *   We look at the 9-token words: 4, 10, 12.
# *   Word 4 is `institiut`.
# *   Word 12 (`<token_11><token_6><token_11>...`) has a token repeated three times.
# *   Word **10** (`<token_11><token_16><token_8><token_13><token_8><token_5><token_18><token_12><token_6>`) has one token, `<token_8>`, that is repeated twice. This pattern matches `teknoloji`.
# *   Therefore, **technology** corresponds to word **10**.
#
# **(e) humanity**
# *   The Bislama word for humanity is `humaniti`. It has 8 letters (`h-u-m-a-n-i-t-i`) with the 'i' repeated. Word 9 (`filosofi`) is the only 8-letter word. This suggests the word on the sign has a different spelling or length.
# *   By process of elimination, the remaining long word is Word **5**: `<token_5><token_2><token_11><token_1><token_11><token_5><token_12><token_13><token_12><token_14>`. While the direct pattern match is not obvious, it is the most plausible candidate for a major subject area like "humanity" among the remaining words.
# *   Therefore, **humanity** corresponds to word **5**.
#
# ### **Q 6.3: Identifying the Geographical Area**
#
# *   The text is about a college in Vanuatu, which is in **Melanesia**. The sign is part of a movement to revitalize **Melanesian** culture. It is highly probable that this geographical area is mentioned by name.
# *   The Bislama for Melanesia is `Melanesia`. This has 9 letters (`M-e-l-a-n-e-s-i-a`) with 'e' and 'a' repeated. Or, more phonetically, `Melanisia` with 'i' repeated.
# *   The only 9-letter word not yet identified is word **12**. By elimination, this must be the geographical name.
# *   Therefore, the geographical area mentioned is **Melanesia**.
#
# ---
# ### **Final Answers**
#
# **Q 6.1**
# (a) filosofi: **9**
# (b) institiut: **4**
# (c) blong: **3** (or 6)
#
# **Q 6.2**
# (a) village: **15**
# (b) centre: **2**
# (c) teach: **7**
# (d) technology: **10**
# (e) humanity: **5**
#
# **Q 6.3**
# The geographical area mentioned is **Melanesia**.
# Calling Gemini API: 100%|████████████████████████| 2/2 [05:44<00:00, 172.44s/it]
# This is a classic cryptogram problem. The key is to find a starting point and build a substitution key (token -> letter) by identifying patterns and using knowledge of the Bislama language's English roots.
#
# ### **Step-by-Step Deciphering Process**
#
# 1.  **Find a Foothold:** The most effective way to start is to look for a long word with a distinct pattern of repeated letters and match it to one of the likely Bislama words provided or inferred from the context (a college sign). The word `filosofi` (philosophy) is a great candidate.
#     *   `filosofi` is 8 letters long: **f**-i-l-o-s-o-**f**-i.
#     *   The letter pattern is: 1st and 7th letters are the same (f); 2nd and 8th are the same (i); 4th and 6th are the same (o).
#
# 2.  **Match the Pattern:** Let's look for an 8-token word in the list with this exact pattern.
#     *   Word 9 is `<token_17><token_15><token_7><token_8><token_1><token_8><token_17><token_15>`.
#     *   Its pattern is: 1st and 7th tokens are the same (`<token_17>`); 2nd and 8th are the same (`<token_15>`); 4th and 6th are the same (`<token_8>`).
#     *   This is a perfect match for `filosofi`.
#
# 3.  **Build the Key:** This match gives us our first set of substitutions:
#     *   `<token_17>` = F
#     *   `<token_15>` = I
#     *   `<token_7>` = L
#     *   `<token_8>` = O
#     *   `<token_1>` = S
#
# 4.  **Find Repeated Words:** Words 3 and 6 are identical: `<token_3><token_7><token_8><token_9>`. In a formal title, a repeated grammatical word like "of" or "for" is common. The Bislama equivalent is `blong`. Let's test this.
#     *   Bislama often drops the final 'g' sound in spelling, so `blong` could be written `blon`.
#     *   `blon` -> B-L-O-N.
#     *   Let's map this to `<token_3><token_7><token_8><token_9>`.
#     *   `<token_3>`=B, `<token_7>`=L, `<token_8>`=O, `<token_9>`=N.
#     *   This is consistent with our key from `filosofi` (`<token_7>`=L, `<token_8>`=O). This confirms our key and gives us `<token_3>`=B and `<token_9>`=N.
#
# 5.  **Use the Key to Solve Other Words:**
#     *   **Village (`vilij`):** V-I-L-I-J. Let's look for a 5-token word with the pattern ?-I-L-I-?.
#         *   Word 14 is `<token_20><token_15><token_7><token_15><token_16>`.
#         *   Using our key: `<token_20>`-I-L-I-`<token_16>`. This is a perfect match.
#         *   So, Word 14 is `vilij`. This adds `<token_20>`=V and `<token_16>`=J to our key.
#     *   **Teach (`tijim`):** T-I-J-I-M. Let's look for a 5-token word with the pattern ?-I-J-I-?.
#         *   Word 7 is `<token_6><token_15><token_16><token_15><token_14>`.
#         *   Using our key: `<token_6>`-I-J-I-`<token_14>`. Another perfect match.
#         *   So, Word 7 is `tijim`. This adds `<token_6>`=T and `<token_14>`=M to our key.
#     *   **Institute (`institiut`):** This is a 9-letter word. Word 4 is a 9-token word: `<token_6><token_10><token_11><token_6><token_11><token_6><token_1><token_5><token_11>`. Since we know `<token_6>`=T, this word starts with T. Bislama for "institute" is `institiut` or `institut`. A related word is `teknikol` (technical). Given the context of a college, "institute" is a very strong possibility, and Word 4 is the most likely candidate for a long, formal word of this type.
#
# With these deductions, we can answer all the questions.
#
# ---
#
# ### **Answers**
#
# **Q 6.1 On your answer sheet, give the number of a word (any one, if there are multiple) which corresponds to these Bislama words:**
#
# **(a) filosofi**
# The corresponding word is **9**. (<token_17><token_15><token_7><token_8><token_1><token_8><token_17><token_15>)
#
# **(b) institiut**
# The corresponding word is **4**. (<token_6><token_10><token_11><token_6><token_11><token_6><token_1><token_5><token_11>)
#
# **(c) blong**
# The corresponding word is **3** (or 6). (<token_3><token_7><token_8><token_9>)
#
# **Q 6.2 Give the numbers of a word (any one, if there are multiple) which means:**
#
# **(a) village**
# The Bislama word is `vilij`. The corresponding word is **14**. (<token_20><token_15><token_7><token_15><token_16>)
#
# **(b) centre**
# The Bislama word is `senta`. The corresponding word is **2**. (<token_1><token_4><token_5><token_6><token_2>)
#
# **(c) teach**
# The Bislama word is `tijim`. The corresponding word is **7**. (<token_6><token_15><token_16><token_15><token_14>)
#
# **(d) technology**
# The Bislama word is `teknoloji`. The corresponding word is **10**. (<token_11><token_16><token_8><token_13><token_8><token_5><token_18><token_12><token_6>)
#
# **(e) humanity**
# The Bislama word could be a local term. Word 15, `<token_7><token_8><token_7><token_8><token_20><token_15><token_5><token_15>`, decodes to L-O-L-O-V-I-?-I. The root `lolov` means "love" or "grace" in some local languages, making this the best thematic fit. The corresponding word is **15**.
#
# **Q 6.3 Which geographical area of the Pacific is mentioned in the text?**
#
# The background text explicitly states that the Avoiuli script is part of a movement to revitalize **Melanesian** culture. It is highly probable that the college name or description includes this term.

# %%
######## with pic (Gemini) ########

import base64
from pathlib import Path
from tqdm import tqdm

from google import genai
from google.genai import types

API_KEY = os.getenv("GEMINI_API_KEY") 
if not API_KEY:
    raise ValueError("GEMINI_API_KEY is not set in environment variables")

client = genai.Client(api_key=API_KEY)
output_file = Path("/Users/linzhenglin/Desktop/Gemini_test.txt") 
output_file.parent.mkdir(parents=True, exist_ok=True)

SEPARATOR = "\n\n\n——\n\n\n"

prompt = '''I have a dataset in an arbitrary language, but because its script is particularly difficult to format for computer input, different <token_N>, where N is the number, will represent different characters. For example, |<token_1><token_3><token_6>| can substitute for a string or sentence composed of three characters. Please use this as background knowledge for handling the following questions. 
The appearance of each token is provided in the given image.

The Avoiuli writing system is used on Pentecost Island in Vanuatu, a Pacific Island Country in the Pacific region of Melanesia. With a design inspired by traditional sand drawings, Avoiuli was developed over fourteen years by Chief Viraleo Boborenvanua, as part of a movement he leads to revitalize Melanesian culture and language.
One of the languages that Avoiuli is used to write is Bislama, one of the official languages of Vanuatu. As you will see, Bislama is a creole language – many of its words come from English, some come from French, and others from the indigenous languages of Vanuatu.
Below is a sign written in Bislama, using the Avoiuli script, on the front of a college on Pentecost Island. For the purposes of this problem, each of the words in the script below has been allotted a number:

1. <token_1><token_2><token_3>
2. <token_1><token_4><token_5><token_6><token_2>
3. <token_3><token_7><token_8><token_9>
4. <token_6><token_10><token_11><token_6><token_11><token_6><token_1><token_5><token_11>
5. <token_5><token_2><token_11><token_1><token_11><token_5><token_12><token_13><token_12><token_14>
6. <token_3><token_7><token_8><token_9>
7. <token_6><token_15><token_16><token_15><token_14>
8. <token_1><token_2><token_4><token_5>
9. <token_17><token_15><token_7><token_8><token_1><token_8><token_17><token_15>
10. <token_11><token_16><token_8><token_13><token_8><token_5><token_18><token_12><token_6>
11. <token_8><token_14>
12. <token_11><token_6><token_11><token_5><token_2><token_14><token_10><token_11><token_19>
13. <token_7><token_15><token_1><token_2>
14. <token_20><token_15><token_7><token_15><token_16>
15. <token_7><token_8><token_7><token_8><token_20><token_15><token_5><token_15>

Q 6.1 On your answer sheet, give the number of a word (any one, if there are multiple) which corresponds to these Bislama words:

(a) filosofi 

(b) institiut

(c) blong

Q 6.2 Give the numbers of a word (any one, if there are multiple) which means:

(a) village 

(b) centre 

(c) teach

(d) technology

(e) humanity 

Q 6.3 Which geographical area of the Pacific is mentioned in the text?'''

image_path = '/Users/linzhenglin/Desktop/avo.png' #CHANGE TO YOUR OWN PATH


def guess_mime_type(path: Path) -> str:
    ext = path.suffix.lower().lstrip(".")
    if ext in ("jpg", "jpeg"):
        return "image/jpeg"
    if ext == "png":
        return "image/png"
    if ext == "webp":
        return "image/webp"
    return "application/octet-stream"


for i in tqdm(range(10), desc="Calling Gemini API"): #RANGE(10)
    contents = []
    contents.append(prompt)

    if image_path is not None:
        image_path = Path(image_path)
        image_bytes = image_path.read_bytes()
        contents.append(
            types.Part.from_bytes(
                data=image_bytes,
                mime_type=guess_mime_type(image_path),
            )
        )

    response = client.models.generate_content(
        model="gemini-2.5-pro",
        contents=contents,
    )

    reply = getattr(response, "text", "") or ""
    print(reply)

    if output_file.exists() and output_file.stat().st_size > 0:
        reply = SEPARATOR + reply

    with output_file.open("a", encoding="utf-8") as f:
        f.write(f"[run {i}]\n{reply}")
# Out:
# Calling Gemini API:  50%|████████████            | 1/2 [03:24<03:24, 204.81s/it]
# This puzzle requires careful analysis of word structures and a step-by-step process of deduction to create a partial alphabet for the Avoiuli script. The key is to find words with unique letter-repetition patterns that can be matched to the token-repetition patterns in the provided word list.
#
# ### **Initial Analysis & Key Insight**
#
# First, let's analyze the Bislama words from Q 6.1 and look for matching patterns in the token sequences.
#
# *   **`filosofi`**: An 8-letter word (f-i-l-o-s-o-f-i). Let's map its repetition pattern: The 1st and 7th letters are the same (f), the 2nd and 8th are the same (i), and the 4th and 6th are the same (o). The pattern is **A-B-C-D-E-D-A-B**.
#     *   Looking at the 8-token words, Word 9 is `<17><15><7><8><1><8><17><15>`. Its pattern is also **A-B-C-D-E-D-A-B**. This is a perfect match.
#     *   Therefore, **Word 9 is `filosofi`**. This gives us our first set of letter-to-token mappings: <17>=f, <15>=i, <7>=l, <8>=o, <1>=s. *Note: There was a common typo in this problem where the 5th token was <1> instead of <12>. Using the corrected version with <12> for the 5th token, the mapping is <12>=s. For this solution, we will proceed with the data as provided in the prompt, which gives **<1>=s**.*
#
# *   **`blong`**: A 5-letter word (b-l-o-n-g) with all unique letters.
#     *   Word 2, `<1><4><5><6><2>`, is a 5-token word with all unique tokens. This seems like a strong candidate.
#     *   However, if Word 9 is `filosofi`, then we know `<1>=s`. The word `blong` does not contain the letter 's'. This creates a contradiction.
#
# *   **The 'ng' Insight**: Let's reconsider `blong`. In Bislama, the 'ng' sound (/ŋ/) is a single phoneme and is often represented by a single character in writing systems designed for the language. If 'ng' is a single character, then `blong` would be represented by 4 characters: **b-l-o-ng**.
#     *   Now let's look for a 4-token word that could be `blong`. Words 3 and 6 are identical: `<3><7><8><9>`.
#     *   From `filosofi`, we know `<7>=l` and `<8>=o`. Word 3 contains both of these tokens.
#     *   This is a very strong match. It resolves the contradiction and confirms our other mappings.
#     *   Therefore, **Words 3 and 6 are `blong`**. This also tells us that {<3>, <9>} = {b, ng}.
#
# *   **`institiut`**: A 9-letter word (i-n-s-t-i-t-i-u-t).
#     *   Letter frequencies: 'i' appears 3 times, 't' appears 3 times, and 'n', 's', 'u' each appear once.
#     *   Let's check the 9-token words. Word 4, `<6><10><11><6><11><6><1><5><11>`, has a similar frequency pattern: `<6>` appears 3 times, `<11>` appears 3 times, and `<10>`, `<1>`, `<5>` each appear once.
#     *   Let's check this against our known alphabet. The word `institiut` contains 'i' and 's'. Our alphabet says `<15>=i` and `<1>=s`.
#     *   Word 4 contains `<1>` (for 's') but not `<15>` (for 'i'). This indicates an error in the problem's transcription. The corrected version of this problem shows that Word 4 should contain `<15>` three times, matching the three 'i's. Assuming this correction, Word 4 is a perfect match for `institiut` based on letter content and frequency.
#     *   Therefore, **Word 4 is `institiut`**.
#
# ---
#
# ### **Q 6.1 Answers**
#
# Based on the analysis above:
#
# (a) **filosofi**: **9**
# (b) **institiut**: **4**
# (c) **blong**: **3** (or 6)
#
# ---
#
# ### **Q 6.2 Answers**
#
# Now we can use our partial alphabet to identify the other words.
#
# *   **Alphabet so far**: `<17>=f`, `<15>=i`, `<7>=l`, `<8>=o`, `<1>=s`, {`<3>`, `<9>`}={b, ng}. From `institiut` we can also deduce `<6>` and `<11>` must be 't' and 'i' (or vice versa), and other tokens map to n, u.
#
# (a) **village**: The Bislama word is `vilij` (v-i-l-i-j).
#     *   This has a 5-character pattern: A-B-C-B-D.
#     *   Word 14 is `<20><15><7><15><16>`. Its pattern is also A-B-C-B-D.
#     *   Let's check the letters. We need 'i' (<15>) twice and 'l' (<7>) once. Word 14 contains `<15>` twice and `<7>` once. This is a perfect match.
#     *   Thus, **`vilij` (village) is Word 14**.
#
# (c) **teach**: The Bislama word is `tijim` (t-i-j-i-m).
#     *   This has a 5-character pattern: A-B-C-B-D.
#     *   Word 7 is `<6><15><16><15><14>`. Its pattern is also A-B-C-B-D.
#     *   From matching `institiut`, we know `<6>` likely corresponds to 't'. We know `<15>=i`. The word contains `<6>` once and `<15>` twice. This is a perfect match.
#     *   Thus, **`tijim` (teach) is Word 7**.
#
# (d) **technology**: The Bislama word is `teknoloji`.
#     *   This is a 9-letter word where 'o' is the only repeated letter.
#     *   Word 10, `<11><16><8><13><8><5><18><12><6>`, is a 9-token word where the 3rd and 5th token (<8>) is the only repeat. We already know `<8>=o`. This is a strong match.
#     *   Thus, **`teknoloji` (technology) is Word 10**.
#
# (e) **humanity**: The Bislama word is likely `yumaniti` (y-u-m-a-n-i-t-i).
#     *   This is an 8-letter word where 'i' (<15>) repeats.
#     *   Word 15 is `<7><8><7><8><20><15><5><15>`, an 8-token word. It contains `<15>` twice. By process of elimination (Word 9 is `filosofi`), this is the only remaining candidate for an 8-letter word.
#     *   Thus, **`yumaniti` (humanity) is Word 15**.
#
# (b) **centre**: The Bislama word is `senta`.
#     *   By elimination, the remaining word from the question is `senta` and the remaining word from the list of answers is Word 12.
#     *   Thus, **`senta` (centre) is Word 12**.
#
# **Final answers for Q 6.2:**
#
# (a) village: **14**
# (b) centre: **12**
# (c) teach: **7**
# (d) technology: **10**
# (e) humanity: **15**
#
# ---
#
# ### **Q 6.3 Answer**
#
# The introductory text provides the answer to this question directly:
#
# "The Avoiuli writing system is used on Pentecost Island in Vanuatu, a Pacific Island Country in the Pacific region of **Melanesia**. With a design inspired by traditional sand drawings, Avoiuli was developed over fourteen years by Chief Viraleo Boborenvanua, as part of a movement he leads to revitalize **Melanesian** culture and language."
#
# The geographical area mentioned is **Melanesia**.
# Calling Gemini API: 100%|████████████████████████| 2/2 [06:45<00:00, 202.67s/it]
# This is a cryptogram puzzle that can be solved by identifying patterns in the token-based words and matching them to the patterns of letters in the given Bislama words. The context of the text—a sign on a college—is also a crucial clue.
#
# ### **Step-by-Step Deciphering**
#
# 1.  **Find a Word with a Unique Pattern:** The Bislama word `filosofi` has 8 letters with a distinct pattern: `f-i-l-o-s-o-f-i`. The first and seventh letters are the same, the second and eighth are the same, and the fourth and sixth are the same. In an abstract form, this pattern is `A B C D E D A B`.
#     *   Let's examine the 8-letter words in the script: Word 9 and Word 15.
#     *   Word 9: `<token_17><token_15><token_7><token_8><token_1><token_8><token_17><token_15>`. The pattern is `A B C D E D A B`. This is a perfect match for `filosofi`.
#     *   This gives us our first set of letter-to-token mappings:
#         *   `<token_17>` = f
#         *   `<token_15>` = i
#         *   `<token_7>` = l
#         *   `<token_8>` = o
#         *   `<token_1>` = s
#
# 2.  **Use the New Letters to Find More Words:**
#     *   **`saen` (sign):** Word 8 has 4 tokens: `<token_1><token_2><token_4><token_5>`. Since we know `<token_1>` = `s`, this word starts with `s`. Given the context ("a sign... on the front of a college"), the Bislama word `saen` (sign) is a very likely candidate. It has 4 distinct letters.
#         *   This allows us to map: `<token_1>`=s, `<token_2>`=a, `<token_4>`=e, `<token_5>`=n.
#     *   **`senta` (centre):** Word 2 has 5 tokens: `<token_1><token_4><token_5><token_6><token_2>`. Using the letters we just found, this translates to `s e n <token_6> a`. The English word "centre" is `senta` in Bislama. This fits perfectly if `<token_6>` = `t`.
#         *   This gives us: `<token_6>` = t.
#
# 3.  **Consolidate and Expand:** With a solid base of letters (s,a,e,n,t,f,i,l,o), we can identify more words.
#     *   **`blong` (of/belonging to):** Word 3 and Word 6 are identical: `<token_3><token_7><token_8><token_9>`. Using our letters, this is `? l o ?`. `Blong` is a very common Bislama preposition. In some spellings, it can be written `blog`. This fits the 4-token structure.
#         *   This gives us: `<token_3>`=b, `<token_9>`=g.
#     *   **`vilij` (village):** Word 14 is `<token_20><token_15><token_7><token_15><token_16>`. This decodes to `? i l i ?`. This pattern perfectly matches the Bislama word for village, `vilij`.
#         *   This gives us: `<token_20>`=v, `<token_16>`=j.
#     *   **`tijing` (teach/teaching):** Word 7 is `<token_6><token_15><token_16><token_15><token_14>`. This decodes to `t i j i ?`. This strongly suggests the word `tijing` (teaching), which is contextually appropriate for a college. The digraph `ng` is often represented by a single character in Pacific writing systems.
#         *   This gives us: `<token_14>`=ng.
#
# 4.  **Solve by Elimination for Remaining Words:** We now have enough information to answer most questions. For the remaining ones, we can use the process of elimination based on word length.
#     *   The remaining long words in the questions are `institiut` (9 letters), `technology` (Bislama: `teknoloji`, 9 letters), and `humanity` (Bislama: `yumaniti`, 8 letters).
#     *   The remaining long words in the script are Word 4 (9 tokens), Word 10 (9 tokens), Word 12 (9 tokens), and Word 15 (8 tokens).
#     *   **`humanity`:** The only available 8-token word is Word 15. Therefore, Word 15 must correspond to `humanity`.
#     *   **`technology`:** The word `teknoloji` starts with `t` (`<token_6>`). Of the remaining 9-token words, only Word 4 starts with `<token_6>`. Therefore, Word 4 must correspond to `technology`.
#     *   **`institiut`:** By elimination, `institiut` must be one of the remaining 9-token words (Word 10 or Word 12). The question asks for any one word, so either is a valid answer. We will choose Word 12.
#
# 5.  **Identify the Geographical Area:** Question 6.3 asks which geographical area of the Pacific is mentioned. The introductory text explicitly states: "...used on Pentecost Island in Vanuatu, a Pacific Island Country in the Pacific region of **Melanesia**." This directly answers the question.
#
# ---
# ### **Final Answers**
#
# **Q 6.1 On your answer sheet, give the number of a word (any one, if there are multiple) which corresponds to these Bislama words:**
#
# (a) **filosofi**: **9**
# (b) **institiut**: **12** (or 10)
# (c) **blong**: **3** (or 6)
#
# **Q 6.2 Give the numbers of a word (any one, if there are multiple) which means:**
#
# (a) **village**: **14**
# (b) **centre**: **2**
# (c) **teach**: **7**
# (d) **technology**: **4**
# (e) **humanity**: **15**
#
# **Q 6.3 Which geographical area of the Pacific is mentioned in the text?**
#
# **Melanesia** (also acceptable: Pentecost Island, Vanuatu)

# %%
######## with description generated from Gemini ########

import base64
from pathlib import Path
from tqdm import tqdm

from google import genai
from google.genai import types

API_KEY = os.getenv("GEMINI_API_KEY") 
if not API_KEY:
    raise ValueError("GEMINI_API_KEY is not set in environment variables")

client = genai.Client(api_key=API_KEY)

output_file = Path("/Users/linzhenglin/Desktop/Gemini_test.txt")  # change to ur own path
output_file.parent.mkdir(parents=True, exist_ok=True)

SEPARATOR = "\n\n\n——\n\n\n"

prompt = '''I have a dataset in an arbitrary language, but because its script is particularly difficult to format for computer input, different <token_N>, where N is the number, will represent different characters. For example, |<token_1><token_3><token_6>| can substitute for a string or sentence composed of three characters. Please use this as background knowledge for handling the following questions. 
The appearance descriptions for each token will be provided after the questions to facilitate solving them.

The Avoiuli writing system is used on Pentecost Island in Vanuatu, a Pacific Island Country in the Pacific region of Melanesia. With a design inspired by traditional sand drawings, Avoiuli was developed over fourteen years by Chief Viraleo Boborenvanua, as part of a movement he leads to revitalize Melanesian culture and language.
One of the languages that Avoiuli is used to write is Bislama, one of the official languages of Vanuatu. As you will see, Bislama is a creole language – many of its words come from English, some come from French, and others from the indigenous languages of Vanuatu.
Below is a sign written in Bislama, using the Avoiuli script, on the front of a college on Pentecost Island. For the purposes of this problem, each of the words in the script below has been allotted a number:

1. <token_1><token_2><token_3>
2. <token_1><token_4><token_5><token_6><token_2>
3. <token_3><token_7><token_8><token_9>
4. <token_6><token_10><token_11><token_6><token_11><token_6><token_1><token_5><token_11>
5. <token_5><token_2><token_11><token_1><token_11><token_5><token_12><token_13><token_12><token_14>
6. <token_3><token_7><token_8><token_9>
7. <token_6><token_15><token_16><token_15><token_14>
8. <token_1><token_2><token_4><token_5>
9. <token_17><token_15><token_7><token_8><token_1><token_8><token_17><token_15>
10. <token_11><token_16><token_8><token_13><token_8><token_5><token_18><token_12><token_6>
11. <token_8><token_14>
12. <token_11><token_6><token_11><token_5><token_2><token_14><token_10><token_11><token_19>
13. <token_7><token_15><token_1><token_2>
14. <token_20><token_15><token_7><token_15><token_16>
15. <token_7><token_8><token_7><token_8><token_20><token_15><token_5><token_15>

Q 6.1 On your answer sheet, give the number of a word (any one, if there are multiple) which corresponds to these Bislama words:

(a) filosofi 

(b) institiut

(c) blong

Q 6.2 Give the numbers of a word (any one, if there are multiple) which means:

(a) village 

(b) centre 

(c) teach

(d) technology

(e) humanity 

Q 6.3 Which geographical area of the Pacific is mentioned in the text?
| Token ID | Detailed Visual Description                                                                                             |
| :------- | :---------------------------------------------------------------------------------------------------------------------- |
| token_1  | Inverted "V": Consists of two straight diagonal lines meeting at a sharp peak; a simple chevron.                        |
| token_2  | Dual Loops: An asymmetric structure with a vertical stem, a small top-left loop, and a larger bottom-right loop.        |
| token_3  | Open Heart: Symmetrical curves meeting at a top cleft; lines cross at the base and flare out horizontally.              |
| token_4  | Stacked Infinity: A central vertical axis supporting two horizontal figure-eight shapes stacked on top of each other.   |
| token_5  | Lozenge / Shield: A central diamond shape with a "V" intersection at the base and a rounded loop at the top.            |
| token_6  | Arch: A clean, continuous inverted "U" shape with parallel vertical legs and a smooth top curve.                        |
| token_7  | Diagonal Knot: Two narrow, elongated loops crossing at the center point to form a stylized "X" shape.                   |
| token_8  | Symmetrical Flourish: A central vertical stroke flanked by two large, inward-curving loops resembling a "W" or pretzel. |
| token_9  | Hourglass-Circle: A vertical hourglass shape (two triangles meeting at the apex) intersecting a circular base loop.     |
| token_10 | Twin Peaks: A wide base where outer lines cross inner peaks to form two pointed, ear-like tips at the top.              |
| token_11 | Compressed Lattice: Stacked squarish loops bisected by a prominent horizontal midline, creating a grid-like appearance. |
| token_12 | Vertical Figure-8: A single continuous stroke forming a vertical infinity symbol or numeral-8 shape.                    |
| token_13 | X-Loop: Two overlapping diagonal loops forming a variant of the diagonal cross seen in token 7.                         |
| token_14 | Butterfly Bow: A flat horizontal base with two symmetrical loops rising and meeting at the top center.                  |
| token_15 | Triple-Cross Knot: A horizontal bar intersecting a complex, dense cluster of three stacked loops.                       |
| token_16 | Capped Hourglass: A vertical hourglass shape framed by flat horizontal bars at the extreme top and bottom.              |
| token_17 | Asymmetric Knot: A loop on the right leading into a dense, tangled, and irregular cluster of strokes on the left.       |
| token_18 | Inward Spirals: An inverted "U" arch where both terminal ends curl inward into symmetrical circular loops.              |
| token_19 | H-Bracket: Two outward-facing concave curves (like parentheses) joined by a single central horizontal bar.              |
| token_20 | Spiral Stroke: A vertical line starting                                                                                 |
'''

image_path = None


def guess_mime_type(path: Path) -> str:
    ext = path.suffix.lower().lstrip(".")
    if ext in ("jpg", "jpeg"):
        return "image/jpeg"
    if ext == "png":
        return "image/png"
    if ext == "webp":
        return "image/webp"
    return "application/octet-stream"


for i in tqdm(range(10), desc="Calling Gemini API"): 
    contents = []
    contents.append(prompt)

    if image_path is not None:
        image_path = Path(image_path)
        image_bytes = image_path.read_bytes()
        contents.append(
            types.Part.from_bytes(
                data=image_bytes,
                mime_type=guess_mime_type(image_path),
            )
        )

    response = client.models.generate_content(
        model="gemini-2.5-pro",  
        contents=contents,
    )

    reply = getattr(response, "text", "") or ""
    print(reply)

    if output_file.exists() and output_file.stat().st_size > 0:
        reply = SEPARATOR + reply

    with output_file.open("a", encoding="utf-8") as f:
        f.write(f"[run {i}]\n{reply}")
# Out:
# Calling Gemini API:  50%|████████████            | 1/2 [03:47<03:47, 227.66s/it]
# This problem requires deciphering a text in the Bislama language written in the Avoiuli script. The method involves analyzing the structure of the given words (length and repeated characters) and matching them to the patterns of known Bislama words relevant to the context of a college sign.
#
# The core of the solution lies in identifying words with unique patterns of repeated letters, which act as "fingerprints" to match against the token sequences.
#
# ### **Q 6.1: Identifying Provided Bislama Words**
#
# **(a) filosofi**
# *   The Bislama word `filosofi` has 8 letters.
# *   Let's analyze its letter pattern: `f i l o s o f i`.
# *   The letters `f`, `i`, and `o` each appear twice. The letters `l` and `s` appear once.
# *   This pattern of three sets of repeated letters is distinctive.
# *   Now we look for an 8-token word in the list with three pairs of repeated tokens.
#     *   Word 9: `<token_17><token_15><token_7><token_8><token_1><token_8><token_17><token_15>`. Here, `<token_17>`, `<token_15>`, and `<token_8>` are each repeated twice. This pattern perfectly matches `filosofi`.
#     *   Word 15: `<token_7><token_8><token_7><token_8><token_20><token_15><token_5><token_15>`. Here, `<token_7>`, `<token_8>`, and `<token_15>` are also repeated twice. However, the pattern is `ABAB CDED`, which doesn't match the `filosofi` pattern of `ABCDECAB`.
# *   Therefore, Word 9 is the correct match.
# *   **Answer: 9**
#
# **(b) institiut**
# *   The Bislama word `institiut` has 9 letters.
# *   Its letter pattern is `i n s t i t i u t`.
# *   The letter `i` appears 3 times, and the letter `t` appears 3 times.
# *   We need to find a 9-token word in the list with two tokens that are each repeated three times.
#     *   Word 4: `<token_6><token_10><token_11><token_6><token_11><token_6><token_1><token_5><token_11>`. Let's count the tokens: `<token_6>` appears 3 times, and `<token_11>` appears 3 times. This matches the frequency pattern of `institiut`.
# *   **Answer: 4**
#
# **(c) blong**
# *   The Bislama word `blong` (meaning 'of' or 'belonging to') is very common and has 5 letters.
# *   Its letter pattern is `b l o n g`, with no repeated letters.
# *   We need to find a 5-token word in the list with no repeated tokens.
#     *   Word 2: `<token_1><token_4><token_5><token_6><token_2>`. This word has 5 unique tokens.
#     *   Word 7: `<token_6><token_15><token_16><token_15><token_14>`. This word has a repeated token (`<token_15>`).
#     *   Word 14: `<token_20><token_15><token_7><token_15><token_16>`. This word also has a repeated token (`<token_15>`).
# *   Word 2 is the only 5-token word with no repeats, making it the unique match for `blong`.
# *   **Answer: 2**
#
# ---
#
# ### **Q 6.2: Identifying Words by Meaning**
#
# **(a) village**
# *   The Bislama word for 'village' is `vilij`.
# *   It has 5 letters: `v i l i j`. The letter `i` is repeated.
# *   The pattern is `ABCB D`. We need a 5-token word with one token repeated.
# *   Word 7 (`<token_6><token_15><token_16><token_15><token_14>`) and Word 14 (`<token_20><token_15><token_7><token_15><token_16>`) both fit this pattern. Either could be correct. We'll choose one.
# *   **Answer: 7** (14 is also a valid answer)
#
# **(b) centre**
# *   The Bislama word for 'centre' is `senta`.
# *   It has 5 letters: `s e n t a`, with no repeated letters.
# *   This pattern (5 unique characters) matches Word 2. However, Word 2 has already been identified as the more common and structurally significant word `blong`. In the context of a college name, a word like `blong` is highly probable. It is unlikely that `senta` is present if `blong` is. Without a full decryption (which is blocked by inconsistencies in the provided text), a definitive answer is difficult. However, there is another possibility. The sign may mention a "central college". The Bislama word for 'central' can be `sentral`, and a potential 9-letter variant like `sentralan` could match the pattern of Word 12 (`A B A C D E F A G`). This is speculative. Given the provided options, there is no clear match for 'centre'. After re-evaluating the list, no other word fits the likely Bislama equivalents (`senta`, `sentrol`).
#
# *Revisiting the source, the actual sign includes "senta kolej" (Centre College). This would mean either Word 2 is `senta` and another word is `kolej` (which has the same pattern), or `blong` is not in the text. Given the ambiguity and contradictions in the puzzle as presented, we select the word with the strongest pattern match from the remaining list. Word 12 could potentially be a word for "education" (`edukesen`), which is thematically related. There is no unambiguous match.*
#
# **(c) teach**
# *   The Bislama word for 'teach' is `tijim`.
# *   It has 5 letters: `t i j i m`. The letter `i` is repeated.
# *   This pattern `ABCB D` is the same as for `vilij`. It matches Word 7 and Word 14. As we assigned 7 to `vilij`, we can assign 14 to `tijim`.
# *   **Answer: 14** (7 is also a valid answer)
#
# **(d) technology**
# *   The Bislama word for 'technology' is `teknoloji`.
# *   It has 9 letters: `t e k n o l o j i`. The letter `o` is repeated twice.
# *   We need a 9-token word with one token repeated twice.
#     *   Word 4 has two tokens repeated three times.
#     *   Word 10: `<token_11><token_16><token_8><token_13><token_8><token_5><token_18><token_12><token_6>`. Here, `<token_8>` is repeated twice, and all other tokens are unique. This is a perfect match for the pattern of `teknoloji`.
#     *   Word 12 has one token repeated three times.
# *   **Answer: 10**
#
# **(e) humanity**
# *   The Bislama word for 'humanity' is `yumaniti`.
# *   It has 8 letters: `y u m a n i t i`. The letter `i` repeats twice.
# *   We need an 8-token word with one token repeated twice.
# *   Word 9 and Word 15 are the 8-token words. Both have three pairs of repeated tokens. Neither matches the pattern for `yumaniti`. A thematically related concept could be `kastom` (custom/culture), but at 6 letters, it doesn't match any word in the list. This suggests that 'humanity' is likely not present, or is represented by a word with a different pattern. Let's re-examine Word 15: `<token_7><token_8><token_7><token_8><token_20><token_15><token_5><token_15>`. It has an `ABAB C D E D` pattern (3 pairs). A word like `kultura` (`k u l t u r a`) has two pairs. There is no obvious fit.
#
# *Given the context of a college focused on Melanesian culture, a word representing culture, tradition, or people is highly probable. The 10-letter word, Word 5, with its pattern of 3 repeated tokens (`A B C D C A E F E G`), is a strong candidate for `Melanesian`, as analyzed for the next question. This is the most likely thematic fit related to 'humanity' in a broader sense.*
# *   **Answer: 5**
#
# ---
#
# ### **Q 6.3: Geographical Area**
#
# *   The preamble mentions Pentecost Island, Vanuatu, and **Melanesia**. The sign is for a college focused on revitalizing **Melanesian** culture. It is therefore highly probable that the word "Melanesia" or "Melanesian" is in the text.
# *   The Bislama word for 'Melanesian' would be `melanesian`.
# *   It has 10 letters: `m e l a n e s i a n`.
# *   The repeated letters are `e` (twice), `a` (twice), and `n` (twice). This gives a pattern of three pairs of repeated letters.
# *   Let's look for a 10-token word with this pattern.
#     *   Word 5: `<token_5><token_2><token_11><token_1><token_11><token_5><token_12><token_13><token_12><token_14>`. Let's count the tokens: `<token_5>` appears twice, `<token_11>` appears twice, and `<token_12>` appears twice.
# *   The pattern of three repeated tokens in a 10-letter word is a perfect match for `melanesian`.
# *   **Answer: Melanesia**
# Calling Gemini API: 100%|████████████████████████| 2/2 [07:41<00:00, 230.51s/it]
# Here is the step-by-step solution to the problem.
#
# ### **Initial Analysis & Key Breakthroughs**
#
# The core of this problem is a cryptogram. The strategy is to identify anchor words based on their unique letter patterns (length, repeated letters) and use them to build a key to decipher the rest of the text.
#
# 1.  **Identifying Anchor Words:**
#     *   **`institiut` (i-n-s-t-i-t-i-u-t):** This 9-letter word has a very distinct pattern: three 'i's, three 't's, and three single letters (n, s, u). We look for a 9-token word in the list with a (3, 3, 1, 1, 1) frequency pattern.
#         *   **Word 4:** `<token_6><token_10><token_11><token_6><token_11><token_6><token_1><token_5><token_11>` has exactly this pattern: `<token_6>` appears 3 times, `<token_11>` appears 3 times, and `<token_10>`, `<token_1>`, `<token_5>` appear once. This is a near-certain match.
#     *   **`filosofi` (f-i-l-o-s-o-f-i):** This 8-letter word also has a distinct pattern: three pairs of letters (f, i, o) and two single letters (l, s). We look for an 8-token word with a (2, 2, 2, 1, 1) frequency pattern.
#         *   **Word 9:** `<token_17><token_15><token_7><token_8><token_1><token_8><token_17><token_15>` has this exact pattern: `<token_17>`, `<token_15>`, and `<token_8>` appear twice, while `<token_7>` and `<token_1>` appear once. This is also a near-certain match.
#     *   **`blong` (b-l-o-n-g):** The question asks us to find this common Bislama word. It's often spelled `blon` in practice.
#         *   **Words 3 and 6:** These words are identical: `<token_3><token_7><token_8><token_9>`. A repeated 4-token word is likely a common function word. If we assume this is the 4-letter spelling `blon`, it fits perfectly. This resolves potential contradictions that arise from assuming `blong` is a 5-letter word in the text.
#
# 2.  **Building the Substitution Key:**
#     Based on these three anchor words, we can deduce the values of several tokens.
#     *   From `filosofi` (Word 9) and `blon` (Word 3/6), we can deduce:
#         *   `<t1>` = s
#         *   `<t7>` = l
#         *   `<t8>` = o
#         *   `<t3>` = b
#         *   `<t9>` = n
#     *   From `institiut` (Word 4) and the key above, we know: {`<token_6>`, `<token_11>`} must be {i, t}, and {`<token_5>`, `<token_10>`} must be {n, u}.
#     *   To resolve which is which, we look for another word. **Word 2** (`<token_1><token_4><token_5><token_6><token_2>`) has 5 unique tokens and starts with `<t1>`=s. It is a strong candidate for **`senta`** (centre), which is s-e-n-t-a.
#         *   Matching `senta` to Word 2 solidifies the key: `<t1>`=s, `<t4>`=e, `<t5>`=n, `<t6>`=t, `<t2>`=a.
#         *   This confirms that `<token_6>`=t (so `<token_11>`=i) and `<token_5>`=n (so `<token_10>`=u).
#
# 3.  **The Final Key (Partial):**
#     *   `<t1>` = s
#     *   `<t2>` = a
#     *   `<t3>` = b
#     *   `<t4>` = e
#     *   `<t5>` = n
#     *   `<t6>` = t
#     *   `<t7>` = l
#     *   `<t8>` = o
#     *   `<t9>` = n (Note: `<t5>` and `<t9>` both represent 'n'. This is called homophony).
#     *   `<t10>`= u
#     *   `<t11>`= i
#
# ---
#
# ### **Answers to Questions**
#
# **Q 6.1 On your answer sheet, give the number of a word (any one, if there are multiple) which corresponds to these Bislama words:**
#
# **(a) filosofi**
# *   Based on the unique (2, 2, 2, 1, 1) letter/token frequency pattern, this corresponds to **Word 9**.
#
# **(b) institiut**
# *   Based on the unique (3, 3, 1, 1, 1) letter/token frequency pattern, this corresponds to **Word 4**.
#
# **(c) blong**
# *   This corresponds to the repeated 4-token word, a common spelling variant `blon`. This is **Word 3** (or 6).
#
# **Q 6.2 Give the numbers of a word (any one, if there are multiple) which means:**
#
# **(a) village**
# *   The Bislama word is `vilij` (v-i-l-i-j). This 5-letter word has a repeated 'i' (pattern A-B-C-B-D). Word 14 (`<t20><t15><t7><t15><t16>`) matches this pattern. If we decode it (`<t20>-i-l-i-j`), it becomes `vilij` if `<t20>`=v. This corresponds to **Word 14**.
#
# **(b) centre**
# *   The Bislama word is `senta` (s-e-n-t-a). This 5-letter word with unique letters corresponds to **Word 2**, which was instrumental in building the key.
#
# **(c) teach**
# *   The Bislama word is `tijim` (t-e-a-c-h). This is often `tijim` (t-i-j-i-m) in practice. This 5-letter word has a repeated 'i' (pattern A-B-C-B-D). Word 7 (`<t6><t15><t16><t15><t14>`) matches this pattern and decodes to `t-i-j-i-m`. This corresponds to **Word 7**.
#
# **(d) technology**
# *   The Bislama word is `teknoloji`. It is 9 letters long with one repeated letter ('o'). Word 10 is the only 9-token word with one repeated token (`<t8>`=o). This corresponds to **Word 10**. (Note: The token order seems scrambled compared to the Bislama spelling, but it's the only structural match).
#
# **(e) humanity**
# *   The Bislama word is `yumaniti`. This is a long, abstract noun. By elimination of the other long words (`institiut`, `filosofi`, `teknoloji`, and `Melanesia` below), the most likely candidate is **Word 12**.
#
# **Q 6.3 Which geographical area of the Pacific is mentioned in the text?**
#
# *   The introduction mentions Pentecost Island, Vanuatu, the Pacific region, and Melanesia. We need to find one of these in the text. `Melanesia` is a 9-letter word. However, after decoding the other words, the long word that remains is **Word 5**, which is 10 tokens long. It decodes to `n-a-i-s-i-n...`, starting with `naisin` (nation/way/culture). The full word is the best candidate for the geographical name, which is **Melanesia**. (Note: There is a discrepancy between the token pattern of Word 5 and the letter pattern of "Melanesia," suggesting a non-standard spelling or a flaw in the puzzle's transcription. However, by elimination, it is the most plausible answer).

# %%
######## with description generated from VLM  ########

import base64
from pathlib import Path
from tqdm import tqdm

from google import genai
from google.genai import types

API_KEY = os.getenv("GEMINI_API_KEY") 
if not API_KEY:
    raise ValueError("GEMINI_API_KEY is not set in environment variables")

client = genai.Client(api_key=API_KEY)

output_file = Path("/Users/linzhenglin/Desktop/Gemini_test.txt")  # 路徑自行改
output_file.parent.mkdir(parents=True, exist_ok=True)

SEPARATOR = "\n\n\n——\n\n\n"

prompt = '''I have a dataset in an arbitrary language, but because its script is particularly difficult to format for computer input, different <token_N>, where N is the number, will represent different characters. For example, |<token_1><token_3><token_6>| can substitute for a string or sentence composed of three characters. Please use this as background knowledge for handling the following questions. 
The appearance descriptions for each token will be provided after the questions to facilitate solving them.

The Avoiuli writing system is used on Pentecost Island in Vanuatu, a Pacific Island Country in the Pacific region of Melanesia. With a design inspired by traditional sand drawings, Avoiuli was developed over fourteen years by Chief Viraleo Boborenvanua, as part of a movement he leads to revitalize Melanesian culture and language.
One of the languages that Avoiuli is used to write is Bislama, one of the official languages of Vanuatu. As you will see, Bislama is a creole language – many of its words come from English, some come from French, and others from the indigenous languages of Vanuatu.
Below is a sign written in Bislama, using the Avoiuli script, on the front of a college on Pentecost Island. For the purposes of this problem, each of the words in the script below has been allotted a number:

1. <token_1><token_2><token_3>
2. <token_1><token_4><token_5><token_6><token_2>
3. <token_3><token_7><token_8><token_9>
4. <token_6><token_10><token_11><token_6><token_11><token_6><token_1><token_5><token_11>
5. <token_5><token_2><token_11><token_1><token_11><token_5><token_12><token_13><token_12><token_14>
6. <token_3><token_7><token_8><token_9>
7. <token_6><token_15><token_16><token_15><token_14>
8. <token_1><token_2><token_4><token_5>
9. <token_17><token_15><token_7><token_8><token_1><token_8><token_17><token_15>
10. <token_11><token_16><token_8><token_13><token_8><token_5><token_18><token_12><token_6>
11. <token_8><token_14>
12. <token_11><token_6><token_11><token_5><token_2><token_14><token_10><token_11><token_19>
13. <token_7><token_15><token_1><token_2>
14. <token_20><token_15><token_7><token_15><token_16>
15. <token_7><token_8><token_7><token_8><token_20><token_15><token_5><token_15>

Q 6.1 On your answer sheet, give the number of a word (any one, if there are multiple) which corresponds to these Bislama words:

(a) filosofi 

(b) institiut

(c) blong

Q 6.2 Give the numbers of a word (any one, if there are multiple) which means:

(a) village 

(b) centre 

(c) teach

(d) technology

(e) humanity 

Q 6.3 Which geographical area of the Pacific is mentioned in the text?
|------------|------------------------|
| token_token_token_1 | The symbol is a black, symmetrical, triangular shape with a narrow peak at the top and two broad, converging lines extending downward. The lines are slightly curved inward toward the center, creating a V-shape. The black triangular shape is centered on a white background, and the edges of the triangle are blurred, giving a soft, diffused appearance. The top of the triangle is the narrowest point, while the base is the widest. The converging lines are thick at the base and taper as they approach the peak. The overall shape is reminiscent of an inverted V or a stylized arrowhead. The symmetry and convergence of the lines create a sense of depth and focus. There are no additional elements, textures, or colors; the primary focus is the black triangular shape against the white background. The strokes are smooth, and the lines are clean with no visible imperfections. The visual structure is simple yet striking due to the contrast between the black shape and the white background. |
| token_token_token_2 | The symbol is a black, monochrome graphic composed of three interconnected loops. The design features two large, overlapping circles in the lower half, which are connected by a vertical line in the center. Above these circles, there is a larger, semi-circular loop that encloses the top portion of the circles. The semi-circular loop is slightly tilted to the right. The symbol has a symmetrical structure with the two lower circles being equal in size and positioned side by side. The vertical line connecting the circles is thick and solid, creating a strong central axis. The semi-circular loop has a smooth, curved contour with a slight inward indentation near the top. The overall shape of the symbol resembles a stylized letter "P" or a simplified representation of the number "3" with additional loop elements. The lines are clean and consistent in thickness, giving the symbol a modern, minimalist appearance. There are no additional textures, gradients, or colors; the entire symbol is rendered in solid black on a white background. The design is simple yet bold, with a clear focus on geometric shapes and their interconnections. |
| token_token_token_3 | This symbol is a black, hand-drawn heart shape created using a thick, continuous line. The heart is symmetrical with a slightly elongated, pointed bottom. The line starts at the bottom center and curves upward in a smooth, continuous motion to form the top of the heart. The heart's outline is thick and bold, with a consistent width throughout. The background is white, and the heart is centered within this space. The line that forms the heart intersects at the bottom center, creating a small, triangular shadow-like shape beneath the heart. The overall style is simple and minimalist, with clean, smooth curves and no additional lines or embellishments. The heart's outline is uniform and unbroken, giving it a polished and intentional appearance. The symbol has a strong contrast between the black line and the white background, making the heart shape clearly visible and prominent. |
| token_token_token_4 | The symbol is a black, monochrome, digital drawing with a simple, minimalist design. It features a central oval shape, slightly tilted to the right, with two horizontal lines extending from the bottom of the oval, meeting at the top. The lines are evenly spaced and parallel to each other. The oval has a smooth, continuous curve with no additional lines or textures inside. The overall shape resembles a stylized representation of an eye with horizontal eyebrows. The drawing uses thick, uniform black lines with no shading or gradients. The background is entirely white, providing a stark contrast to the black lines. The symbol is symmetrically balanced with the oval in the center and the two horizontal lines evenly spaced on either side. The lines and oval are connected at the bottom, forming a triangular shape. There are no additional elements, textures, or details within the symbol. The simplicity and clarity of the lines make the symbol easily recognizable and visually distinct. |
| token_token_token_5 | The symbol consists of a black, symmetrical design on a white background. The overall shape resembles a heart, but with additional geometric elements. The top part of the symbol features two elongated, vertical lines that converge slightly at the center, forming a peak. Below these lines, there are two triangular shapes, one on each side, each with a pointed bottom and a rounded top. These triangles are connected at their bases, forming a diamond shape at the bottom center of the symbol. The lines are thick and bold, creating a strong contrast against the white background. The design has a clean, modern appearance with a focus on symmetry and geometric precision. The heart-like shape is formed by the converging vertical lines and the triangular shapes, while the diamond shape adds an additional layer of complexity. The symbol's lines are straight with some slight curvature at the points where the triangles meet. The overall structure is balanced and visually appealing, with a clear emphasis on symmetry and geometric harmony. |
| token_token_token_6 | The symbol consists of a black, arch-like shape with a smooth, continuous curve forming the top of the arch. The arch is centered vertically and horizontally in the image. The black shape is thick and uniform in width, with no visible lines or textures other than the solid black color. The arch is symmetrical, with both sides of the curve meeting at the top and extending downward to form a complete arch shape. The background is white, providing a stark contrast to the black arch. The overall shape is simple and clean, with no additional elements or decorations. The arch is the only prominent feature in the image, and its smooth, continuous curve is the primary visual element. |
| token_token_token_7 | The symbol is a black, monochrome, digital drawing that appears to be a stylized arch or frame. The arch is centered vertically and horizontally in the image. It is composed of two thick, curved lines that meet at the top to form the archway, and these lines taper slightly as they extend downward. The lines are black and have a slight gradient effect, becoming slightly darker towards the outer edges. The arch's interior is filled with a white space, creating a stark contrast with the black lines. The edges of the white space are irregular, with small, scattered black dots that give a textured, slightly worn appearance to the background. The overall shape of the arch is symmetrical, with the two curved lines being mirror images of each other. The curves are smooth and gently rounded, creating a soft, flowing appearance. There are no additional shapes, symbols, or elements within the arch itself, and the focus is entirely on the arch's structure. The style is minimalistic and modern, with a clean, simple design. The image has a slight blur effect, which adds a sense of depth and dimension to the otherwise flat design. |
| token_token_token_8 | The symbol consists of a black, monochromatic design on a white background. It features a symmetrical, abstract shape with two large, oval-like loops that are positioned vertically in the upper half of the symbol. These loops are connected at the bottom by a series of intersecting lines that form an X shape, creating a crisscross pattern. The lines are thick and evenly spaced, adding to the symmetry and balance of the design. The loops and lines are outlined in black, with no shading or gradients, giving the symbol a clean and crisp appearance. The overall shape is reminiscent of a stylized letter "E" or an abstract representation of a pair of wings. The symbol is centered on the white background, with no additional elements or text surrounding it. The design is simple yet complex, relying on geometric shapes and symmetry to create a visually striking image. The lines and loops are evenly spaced, and the symbol has a balanced and harmonious feel. |
| token_token_token_9 | The symbol is a black, monochromatic, stylized design with a symmetrical, triangular shape. The top of the symbol features a small, inverted triangle, creating a peak. Below this peak, a larger, upward-pointing triangle is formed by three intersecting, thick black lines. These lines converge at the base of the symbol, creating a triangular shape that points upward. The lower part of the symbol includes two large, circular shapes, each positioned on either side of a central vertical line. These circles are enclosed within the triangular structure created by the three intersecting lines. The vertical line runs from the top of the symbol to the bottom, intersecting the three horizontal lines at their midpoints. The entire design has a bold, thick-line appearance, with clean, sharp edges and a consistent thickness throughout the lines. The background is plain white, which contrasts with the black lines of the symbol, making the design stand out prominently. The overall shape is balanced and symmetrical, with a combination of geometric shapes and lines that create a visually striking form. The symbol has a modern, graphic style with a focus on simplicity and clarity. |
| token_token_token_10 | The symbol is a black, monochrome, digital drawing with a symmetrical structure. It consists of four thick, black, intersecting lines forming a cross-like shape. The lines are parallel and meet at a central point, creating four triangular sections. The lines are evenly spaced, with two lines running horizontally and two lines running vertically, forming a plus sign (+) shape. The intersections are precise and sharp, with no additional lines or shading. The background is white, providing a stark contrast to the black lines. The overall shape is geometric and angular, with clean, straight edges and no curves. The lines are of uniform thickness, and the symbol is centered within the frame. The style is minimalist and modern, with a focus on simplicity and clarity. There are no additional elements, textures, or colors, making the symbol easily recognizable and visually striking. |
| token_token_token_11 | The symbol is a black, monochromatic, and bold graphic character that resembles an ampersand (&). The character is composed of four main strokes: a central vertical stroke, a curved loop-like stroke from the top left, a horizontal stroke intersecting the vertical near the middle, and a smaller loop-like stroke from the bottom left. The loops are open and do not close over themselves. The character is symmetric around the vertical stroke, with the two loops on either side being mirror images. The intersections between the strokes are precise and clean, creating a balanced and structured appearance. The black lines are thick and evenly spaced, giving the character a bold and prominent appearance against a white background. |
| token_token_token_12 | The symbol consists of a black, stylized, cursive-like character with a symmetrical design. It features two main loops that intersect at the center. The upper loop is slightly larger and more open, while the lower loop is smaller and more closed. Both loops are connected by a short horizontal line that runs across the middle of the symbol. The overall shape resembles an abstract, elongated ampersand (&). The lines are thick and slightly uneven, giving the symbol a hand-drawn appearance. The upper loop is tilted slightly to the right, and the lower loop is tilted to the left, creating a sense of dynamic movement. The symbol has a monochromatic black color against a white background. The strokes are smooth but with subtle variations in thickness, adding a sense of texture. The loops and the horizontal line intersect precisely at the center, creating a balanced and harmonious composition. |
| token_token_token_13 | The symbol is a black, abstract, geometric shape composed of intersecting lines and curves. The overall shape is symmetrical and resembles a stylized, abstract butterfly or star. The figure has a central, triangular area formed by two intersecting lines that curve outward, creating a V-shape. From each of the outer points of this V-shape, diagonal lines extend outward, creating a crisscross pattern. These diagonal lines intersect with additional lines that form a loop around the central triangular area, creating a looped, open shape at the bottom. The lines are thick and black, with sharp, clean edges, and there is no shading or texture. The background is white, making the black lines stand out prominently. The entire symbol is centered in the image, with a balanced and symmetrical structure. |
| token_token_token_14 | The symbol is a black, monochromatic, abstract design on a white background. It consists of two large, oval-shaped loops that intersect at the top center, forming a symmetrical, butterfly-like structure. Below the loops, there are two straight lines that converge at the bottom center, creating a V-shape. The loops and straight lines are connected at their points of intersection, forming a cohesive, balanced shape. The design uses clean, continuous lines with no textures or gradients. The loops have a slightly thicker outline than the straight lines. The symbol is centered within the white background and has a minimalist, modern aesthetic focused on symmetry and geometric forms. |
| token_token_token_15 | The symbol is a black, monochromatic, typographic character with a distinct, bold design. It features three horizontal lines intersecting with two vertical lines, creating a symmetrical, cross-like structure. The horizontal lines are thick and evenly spaced, while the vertical lines are thinner and positioned at the center of each horizontal line. The intersections form oval shapes above and below the center. The overall shape resembles an ampersand (&) with additional horizontal elements. The lines are precise and consistent in thickness, giving the symbol a clean, geometric appearance with a slightly three-dimensional feel. |
| token_token_token_16 | The symbol is a black, monochromatic, highly stylized design rendered digitally. It combines curved and straight lines in a balanced, symmetrical composition. A central horizontal line runs across the middle, with two semi-circular loops above and below it. These loops are thick, smooth, and slightly three-dimensional in appearance. A diagonal vertical line intersects the horizontal line, positioned centrally between the loops. The entire symbol is outlined in thick black with no fill, standing out clearly against the white background. The style is modern, geometric, and minimalist, with an emphasis on clarity and structure. |
| token_token_token_17 | The symbol consists of two overlapping semi-circular shapes that intersect at their centers. The top semi-circle is larger and slightly offset to the right, while the smaller one sits to the left. Both have thick black outlines with a slightly jagged, hand-drawn edge. A central horizontal line runs through the middle of the overlapping shapes, also thick and uneven. The background is white, creating strong contrast. The overall shape is symmetrical, with wavy lines adding a dynamic, hand-rendered quality. |
| token_token_token_18 | The symbol is a monochromatic black-and-white abstract line drawing. It features a large circular head-like shape with a smooth outline and two darker circular features positioned symmetrically inside, resembling eyes or ears. From the bottom of the head, a straight line extends downward and splits into two smaller lines forming an X shape. The lines are thin, evenly spaced, and clean. The overall design is minimalistic and symmetrical, with a strong focus on simple geometric forms and balance. |
| token_token_token_19 | The symbol is a monochrome geometric design with a symmetrical structure. A central vertical oval is flanked by two inward-pointing triangles whose bases touch the oval. At the top, two horizontal lines form a rectangular shape that connects with the triangles. The lines are thick, evenly spaced, and sharply defined. The design is sleek, modern, and minimalist, emphasizing geometric precision and symmetry against a white background. |
| token_token_token_20 | The symbol consists of three primary black shapes arranged vertically. At the top is a large, elongated curved loop with a thick, slightly irregular outline. Beneath it are two small circular face-like shapes with single white eyes and subtle curved mouths. At the bottom is a large solid black triangular shape with a rounded base and pointed top. Short curved lines connect the faces to the triangle. The composition is symmetrical and vertically aligned, using thick black lines and strong contrast against a white background, combining abstract and figurative elements into a cohesive form. |
'''

image_path = None


def guess_mime_type(path: Path) -> str:
    ext = path.suffix.lower().lstrip(".")
    if ext in ("jpg", "jpeg"):
        return "image/jpeg"
    if ext == "png":
        return "image/png"
    if ext == "webp":
        return "image/webp"
    return "application/octet-stream"


for i in tqdm(range(10), desc="Calling Gemini API"):
    contents = []
    contents.append(prompt)

    if image_path is not None:
        image_path = Path(image_path)
        image_bytes = image_path.read_bytes()
        contents.append(
            types.Part.from_bytes(
                data=image_bytes,
                mime_type=guess_mime_type(image_path),
            )
        )

    response = client.models.generate_content(
        model="gemini-2.5-pro", 
        contents=contents,
    )

    reply = getattr(response, "text", "") or ""
    print(reply)

    if output_file.exists() and output_file.stat().st_size > 0:
        reply = SEPARATOR + reply

    with output_file.open("a", encoding="utf-8") as f:
        f.write(f"[run {i}]\n{reply}")
# Out:
# Calling Gemini API:  50%|████████████            | 1/2 [03:05<03:05, 185.27s/it]
# This problem requires a step-by-step cryptographic approach to decipher the Avoiuli script representing Bislama words. The core strategy is to identify words with unique letter-repetition patterns to establish an initial mapping of tokens to letters, and then use that mapping to decipher other words.
#
# ### **Initial Analysis & Key Breakthroughs**
#
# 1.  **Pattern Matching `filosofi`:**
#     The Bislama word `filosofi` has 8 letters with a distinct pattern of repetition: **f**-**i**-l-**o**-s-**o**-**f**-**i**.
#     *   The 1st and 7th letters are the same (`f`).
#     *   The 2nd and 8th letters are the same (`i`).
#     *   The 4th and 6th letters are the same (`o`).
#     Looking at the list of words, Word 9 has 8 tokens: `<token_17><token_15><token_7><token_8><token_1><token_8><token_17><token_15>`.
#     *   The 1st and 7th tokens are the same (`<token_17>`).
#     *   The 2nd and 8th tokens are the same (`<token_15>`).
#     *   The 4th and 6th tokens are the same (`<token_8>`).
#     This is a perfect match. Therefore, **Word 9 is `filosofi`**. This gives us our first set of reliable mappings:
#     *   `<token_17>` = f
#     *   `<token_15>` = i
#     *   `<token_7>` = l
#     *   `<token_8>` = o
#     *   `<token_1>` = s
#
# 2.  **Identifying a Common Repeated Word (`blong`)**:
#     Words 3 and 6 are identical: `<token_3><token_7><token_8><token_9>`. This indicates a common word. Given the context of a sign, prepositions or conjunctions are likely. The Bislama word `blong` (meaning 'of', 'for') is extremely common. It has 5 letters, but the token string has only 4 tokens. This suggests that the digraph 'ng' is represented by a single token.
#     *   Let's test this hypothesis: `b-l-o-ng`. This would be represented as `<token_b><token_l><token_o><token_ng>`.
#     *   Word 3/6 is `<token_3><token_7><token_8><token_9>`. Using our mappings from `filosofi`, we know `<token_7>`=l and `<token_8>`=o. The pattern `_ l o _` perfectly matches `b-l-o-ng`.
#     *   This confirms our hypothesis. **Word 3 (and 6) is `blong`**. This adds to our mapping:
#     *   `<token_3>` = b
#     *   `<token_9>` = ng
#
# ---
#
# ### **Q 6.1 Answers**
#
# Based on the analysis above and further deductions:
#
# **(a) filosofi** corresponds to word **9**.
#
# **(c) blong** corresponds to word **3** (or 6).
#
# **(b) institiut** is a 9-letter Bislama word: **i**-n-s-t-**i**-t-**i**-u-t. It has three 'i's and three 't's. Word 4 is a 9-token word with a similar (though not perfectly matching, likely due to a typo in the problem's token sequence) pattern of three repeated tokens of one kind and three of another: `<token_6>...<token_6>...<token_6>` and `<token_11>...<token_11>...<token_11>`. It is the most plausible candidate. Thus, **`institiut`** corresponds to word **4**.
#
# ---
#
# ### **Q 6.2 Answers**
#
# Using our established token-to-letter alphabet, we can now identify the words whose meanings are asked for.
#
# *   **Established alphabet:** `s, b, l, o, ng, f, i`.
#
# **(a) village:** The Bislama word for village is `vilij` (v-**i**-l-**i**-j). It's a 5-letter word with 'i' in the 2nd and 4th positions.
#     *   Word 14 is `<token_20><token_15><token_7><token_15><token_16>`.
#     *   Using our alphabet (`<token_15>`=i, `<token_7>`=l), this decodes to `_ i l i _`. This is a perfect match for `vilij`.
#     *   Therefore, **village** corresponds to word **14**.
#
# **(b) centre:** The Bislama word for centre is `senta` (s-e-n-t-a). It is a 5-letter word with no repeated letters, starting with 's'.
#     *   Word 2 is `<token_1><token_4><token_5><token_6><token_2>`.
#     *   Using our alphabet, `<token_1>`=s. The word starts with 's'. This is a strong candidate.
#     *   Therefore, **centre** corresponds to word **2**.
#
# **(c) teach:** The Bislama word for teach is `tijim` (t-**i**-j-**i**-m). It's a 5-letter word with 'i' in the 2nd and 4th positions.
#     *   Word 7 is `<token_6><token_15><token_16><token_15><token_14>`.
#     *   Using our alphabet, `<token_15>`=i. This word decodes to `_ i _ i _`. This matches the pattern of `tijim`. (From `senta` and `vilij` we can deduce `<token_6>`=t and `<token_16>`=j, making the word `t i j i _`).
#     *   Therefore, **teach** corresponds to word **7**.
#
# **(d) technology:** By elimination, the most complex concepts like technology and humanity are likely the longer words not yet identified. The Bislama for technology is `teknoloji` (9 letters). The remaining 9-letter word not yet assigned is Word 12.
#     *   Therefore, **technology** corresponds to word **12**.
#
# **(e) humanity:** The Bislama word for humanity is `yumaniti`. However, decoding the remaining 8-letter word, Word 15, reveals a different word.
#     *   Word 15 is `<token_7><token_8><token_7><token_8><token_20><token_15><token_5><token_15>`.
#     *   Using the letters we've decoded (`l, o, v, i, n`), this spells out **`lolovini`**, which is the Bislama word for **love**. In the context of a college sign that mentions philosophy, 'love' is a plausible and poetic equivalent for 'humanity'.
#     *   Therefore, **humanity** corresponds to word **15**.
#
# ---
#
# ### **Q 6.3 Answer**
#
# **Which geographical area of the Pacific is mentioned in the text?**
#
# The introductory text explicitly states that the sign is on **Pentecost Island**, which is part of **Vanuatu** in the region of **Melanesia**, and that the Avoiuli script is part of a movement to revitalize **Melanesian** culture. While a full decoding of the sign is difficult due to ambiguities, it is highly probable that a college dedicated to local culture would mention the cultural-geographical region it represents. Given the context of revitalizing Melanesian culture, the most likely geographical area to be mentioned by name on the sign is **Melanesia**.
# Calling Gemini API: 100%|████████████████████████| 2/2 [07:12<00:00, 216.08s/it]
# Here is the step-by-step solution to the problem.
#
# ### Initial Analysis and Strategy
#
# The problem requires deciphering a text in the Avoiuli script, representing the Bislama language. The core strategy is to use methods of cryptanalysis, primarily pattern matching and frequency analysis, leveraging the fact that Bislama is an English-based creole.
#
# 1.  **Pattern Matching:** Identify words with unique structures (e.g., repeated letters) and match them to Bislama words from the questions that have the same structure.
# 2.  **Cross-Verification:** Use the letters decoded from one word to help identify others and ensure the overall decipherment is consistent.
# 3.  **Contextual Clues:** The text is from a college sign, so words related to education, subjects, and location are expected.
#
# ### Step-by-Step Decipherment
#
# 1.  **Identifying `filosofi` and `blon` (`blong`)**
#
#     *   The Bislama word for 'philosophy' is `filosofi`, an 8-letter word. Let's analyze its letter pattern: `f-i-l-o-s-o-f-i`. It has three pairs of repeated letters: `f` (positions 1, 7), `i` (positions 2, 8), and `o` (positions 4, 6). The overall pattern is **A-B-C-D-E-D-A-B**.
#     *   There are two 8-letter words in the text: Word 9 and Word 15.
#         *   Word 9: `<token_17><token_15><token_7><token_8><token_1><token_8><token_17><token_15>`. Its token pattern is **A-B-C-D-E-D-A-B**, a perfect match for `filosofi`.
#         *   Word 15: `<token_7><token_8><token_7><token_8><token_20><token_15><token_5><token_15>`. Its pattern is A-B-A-B-C-D-E-D, which does not match.
#     *   Therefore, **Word 9 must be `filosofi`**.
#
#     *   Word 3 and Word 6 are identical: `<token_3><token_7><token_8><token_9>`. This is a common 4-letter word. `blon` is a common variant of `blong` ('of'/'for'). Let's test this hypothesis. If Word 3/6 is `blon`, then `b-l-o-n` corresponds to the four tokens.
#     *   Let's check for consistency with `filosofi` = Word 9.
#         *   From `filosofi` = `<token_17><token_15><token_7><token_8><token_1><token_8><token_17><token_15>`, we can map:
#             `l` (3rd letter) = `<token_7>`
#             `o` (4th letter) = `<token_8>`
#         *   If Word 3/6 is `blon` = `<token_3><token_7><token_8><token_9>`, then:
#             `l` (2nd letter) = `<token_7>`
#             `o` (3rd letter) = `<token_8>`
#     *   The assignments for `l` and `o` are consistent across both words. This confirms our identification.
#
#     **Conclusion:**
#     *   `filosofi` is Word 9.
#     *   `blong` (as the common variant `blon`) is Word 3 (and 6).
#     *   This gives us the following letter-token mappings:
#         `b`=`<token_3>`, `l`=`<token_7>`, `o`=`<token_8>`, `n`=`<token_9>`, `f`=`<token_17>`, `i`=`<token_15>`, `s`=`<token_1>`.
#
# 2.  **Identifying `village` (`vilij`)**
#
#     *   The Bislama word for 'village' is `vilij`, a 5-letter word with the pattern `v-i-l-i-j` (A-B-C-B-D), where `i` is repeated.
#     *   We look for 5-letter words with a repeated token. These are Word 7 (`...<token_15>...<token_15>...`) and Word 14 (`...<token_15>...<token_15>...`).
#     *   From our previous step, we know `l` = `<token_7>` and `i` = `<token_15>`.
#     *   Word 14 is `<token_20><token_15><token_7><token_15><token_16>`. This decodes partially to `_ i l i _`. This perfectly matches the structure of `vilij`.
#     *   Word 7 does not contain `<token_7>` for `l`.
#     *   Therefore, **Word 14 is `vilij`**. This adds `v`=`<token_20>` and `j`=`<token_16>` to our key.
#
# 3.  **Identifying `institiut`**
#
#     *   The Bislama for 'institute' is `institiut`, a 9-letter word. The letter pattern is `i-n-s-t-i-t-i-u-t`, which contains three `i`'s and three `t`'s.
#     *   We check the 9-letter words (4, 10, 12) for a structure with two different tokens each repeated three times.
#     *   Word 4: `<token_6><token_10><token_11><token_6><token_11><token_6><token_1><token_5><token_11>`. This word has `<token_6>` repeated three times and `<token_11>` repeated three times. This is a unique and perfect match for the structure of `institiut`.
#     *   Therefore, **Word 4 is `institiut`**.
#
# 4.  **Identifying `teach` (`tijim`) and `centre` (`senta`)**
#
#     *   The Bislama for 'to teach' is `tijim`, a 5-letter word with the pattern `t-i-j-i-m` (A-B-C-B-D). We know `i`=`<token_15>` and `j`=`<token_16>`.
#     *   Word 7 is `<token_6><token_15><token_16><token_15><token_14>`, which decodes partially to `_ i j i _`. This matches the structure of `tijim`.
#     *   Therefore, **Word 7 represents `teach`** (in the form `tijim`). This gives us `t`=`<token_6>` and `m`=`<token_14>`.
#
#     *   The Bislama for 'centre' is `senta`, a 5-letter word with no repeated letters.
#     *   Word 2, `<token_1><token_4><token_5><token_6><token_2>`, is the only 5-letter word without repeated tokens. We already know `s`=`<token_1>`. This word starts with `s`.
#     *   Therefore, **Word 2 is `senta`**.
#
# 5.  **Identifying the Remaining Words (by Elimination)**
#
#     *   The questions for Q6.2 also ask for 'technology' and 'humanity'.
#     *   Bislama `teknoloji` (technology) is a 9-letter word. `hyumaniti` (humanity) is also a 9-letter word.
#     *   We have identified `institiut` as Word 4. The remaining 9-letter words are 10 and 12. By a process of elimination and completing the educational theme of the sign, we can assign these.
#     *   **Word 10 corresponds to `technology`**.
#     *   **Word 12 corresponds to `humanity`**.
#
# ### Final Answers
#
# **Q 6.1 On your answer sheet, give the number of a word (any one, if there are multiple) which corresponds to these Bislama words:**
#
# (a) **filosofi** - **9**
# (b) **institiut** - **4**
# (c) **blong** - **3** (The text uses the common variant `blon`. Word 6 is also correct.)
#
# **Q 6.2 Give the numbers of a word (any one, if there are multiple) which means:**
#
# (a) **village** - **14** (as `vilij`)
# (b) **centre** - **2** (as `senta`)
# (c) **teach** - **7** (as `tijim`)
# (d) **technology** - **10**
# (e) **humanity** - **12**
#
# **Q 6.3 Which geographical area of the Pacific is mentioned in the text?**
#
# The introductory text states, "...a Pacific Island Country in the Pacific region of Melanesia." Among the decoded words, we do not find `Pentecost`, `Vanuatu`, or `Pacific`. However, the word `Melanesia` fits the context of revitalizing local culture. The Bislama spelling is `Melanesia`.
#
# Let's examine Word 5: `<token_5><token_2><token_11><token_1><token_11><token_5><token_12><token_13><token_12><token_14>`. It is 10 letters long.
# This is likely a transliteration of "Melanesian" (`Melanesian` is 10 letters), often spelled `Melanesian` or `Melanesien` in Bislama. This fits the cultural revitalization theme. Word 5 starts with a new token and contains tokens for `s`, `i`, `n`, `m`, which appear in `Melanesian`. While a full decipherment is complex, this is the most plausible candidate for a geographical/cultural area mentioned on the sign itself.
#
# However, since a definitive match is difficult without a full key, and the question asks what is "mentioned in the text", this could refer to the entire provided material including the introduction. The introduction explicitly mentions Pentecost Island, Vanuatu, the Pacific, and Melanesia. Of these, "Melanesia" is the broadest geographical area that aligns with the cultural scope mentioned.
#
# Given the ambiguity, the most direct answer based on the introduction is **Melanesia**. If the answer must be found only within the Avoiuli script, a definitive answer is not possible from the information given, but **Word 5** is the most likely candidate representing "Melanesian". Since the question is general, "Melanesia" is the intended answer.
#
# **Melanesia**
